# %% [markdown]
# **Reading the Csv files***

# %%
import pandas as pd #===> Dataframe operations
import numpy as np #===>Math operations
import matplotlib.pyplot as plt #===>Diagram/plots
import seaborn as sns #===>Diagram/plots

# %%
#data set name: visadataset
#read the csv file: comma separated values
#extension: .csv
#you can read this using pandas package

# read excel file
#extension: .xlsx

# %%
#path
#file locations+name+extention
path=r"C:\Users\veeranna\DATA SCIENCE\Data_sets\Visadataset.xlsx"

# %%
pd.read_excel(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N          14513.0       2007.0
# ...

# %%
path=r"C:\Users\veeranna\DATA SCIENCE\Data_sets\bank.xlsx"
pd.read_excel(path)
# Out:
#        age            job  marital  education default  balance housing loan  \
# 0     30.0     unemployed  married    primary      no   1787.0      no   no
# 1     33.0       services  married  secondary      no   4789.0     yes  yes
# 2     35.0     management   single   tertiary      no   1350.0     yes   no
# 3     30.0     management  married   tertiary      no   1476.0     yes  yes
# 4     59.0    blue-collar  married  secondary      no      0.0     yes   no
# ...    ...            ...      ...        ...     ...      ...     ...  ...
# 4516  33.0       services  married  secondary      no   -333.0     yes   no
# 4517  57.0  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518  57.0     technician  married  secondary      no    295.0      no   no
# 4519  28.0    blue-collar  married  secondary      no   1137.0      no   no
# 4520  44.0   entrepreneur   single   tertiary      no   1136.0     yes  yes
#
# ...

# %% [markdown]
# # Creat dataframs usinf list

# %%
name=['Ramesh','Suresh','Satish']
age=[30,35,40]
name,age
# Out:
# (['Ramesh', 'Suresh', 'Satish'], [30, 35, 40])

# %% [markdown]
# **step-1**
# # Creating data frame

# %%
pd.DataFrame() #make the dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **step-2**
# # Providing data

# %%
pd.DataFrame(zip(name,age))
# Out:
#         0   1
# 0  Ramesh  30
# 1  Suresh  35
# 2  Satish  40

# %% [markdown]
# **step-3**
# # provide columns

# %%
#provide columns
data=zip(name,age)
pd.DataFrame(data,columns=['name','age'])
# Out:
#      name  age
# 0  Ramesh   30
# 1  Suresh   35
# 2  Satish   40

# %%
pd.DataFrame(zip(name,age),columns=['name','age'])
# Out:
#      name  age
# 0  Ramesh   30
# 1  Suresh   35
# 2  Satish   40

# %% [markdown]
# **step-4**
# # providinf index

# %%
pd.DataFrame(zip(name,age),columns=['name','age'],index=[1,2,3])
# Out:
#      name  age
# 1  Ramesh   30
# 2  Suresh   35
# 3  Satish   40

# %%
pd.DataFrame()

# %%
data=zip(name,age)
ind=['A','B','C']
col=['name','age']
pd.DataFrame(data,columns=col,index=ind)
# Out:
#      name  age
# A  Ramesh   30
# B  Suresh   35
# C  Satish   40

# %% [markdown]
# step-5
# # adding new column

# %%
name=['Ramesh','Suresh','Satish']
age=[30,35,40]
data=zip(name,age)
ind=['A','B','C']
col=['name','age']
df=pd.DataFrame(data,columns=col,index=ind)
df
# Out:
#      name  age
# A  Ramesh   30
# B  Suresh   35
# C  Satish   40

# %% [markdown]
# - If you want to add new column
#
# - df['new column']
#
# - you need to have a list which is having some elements
#
# - And that elements need to be equal to number of rows
#
# - city_name=['Hyd','Blr','Chennai']
#
# - def['city']=city_name

# %%
city_name=['Hyd','Blr','Chennai']
df['City']=city_name
df
# Out:
#      name  age     City
# A  Ramesh   30      Hyd
# B  Suresh   35      Blr
# C  Satish   40  Chennai

# %% [markdown]
# **step-6**
# # Update the existing column

# %% [markdown]
# - if youu want to creat new columnm or update new column
# - both are done same way

# %%
df['Name']=['Swamy','Asif','Sathwik']
df['name']=['Swamy','Asif','Sathwik']
df
# Out:
#    age     City     Name     name
# A   30      Hyd    Swamy    Swamy
# B   35      Blr     Asif     Asif
# C   40  Chennai  Sathwik  Sathwik

# %% [markdown]
# **step-7**
# # drop the column

# %% [markdown]
# - In order to drop the column
#
# - we need to use drop method
#
# - it takes 3 parameters
#
#     - drop column or row
#
#     - if column then mention column name
#
#     - asix
#         - axis=1 referance as column
#
#         - axis=0 referance as row
#
#     - you want to create a new dataframe or
#
#     - you want to overwrite the existing dataframe
#
#         - inplace=True

# %%
df.drop('Name',axis=1,inplace=True)
df
# Out:
#    age     City     name
# A   30      Hyd    Swamy
# B   35      Blr     Asif
# C   40  Chennai  Sathwik

# %% [markdown]
# **step-8**
# # Drop row

# %%
df.drop('C',axis=0,inplace=True)

# %% [markdown]
# **step-9**
# # Save the data frame

# %%
df.to_csv("output.csv")
#while saving index is considered as extra column
#df.to_excel("output.xlsx")

# %%
#read the output csv
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0  age City   name
# 0          A   30  Hyd  Swamy
# 1          B   35  Blr   Asif

# %% [markdown]
# **step-10**
# # remove index

# %%
# to avoid the above problem
# give index= False
df.to_csv("output.csv",index=False)
pd.read_csv("output.csv")
# Out:
#    age City   name
# 0   30  Hyd  Swamy
# 1   35  Blr   Asif

# %% [markdown]
# # Create data frame with dictionary

# %%
d1={"NAME":['Ramesh','Suresh','Satish'],"AGE":[30,35,40]}
pd.DataFrame(d1)
# no need of zip
# no need of column names
# Out:
#      NAME  AGE
# 0  Ramesh   30
# 1  Suresh   35
# 2  Satish   40
