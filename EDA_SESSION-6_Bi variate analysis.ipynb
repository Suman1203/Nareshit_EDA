# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\veeranna\DATA SCIENCE\Data_sets\Visadataset.xlsx"
visa_df=pd.read_excel(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N          14513.0       2007.0
# ...

# %% [markdown]
# **Catagorical Vs catagorical**

# %%
# continent
# case_study
# as we know that there are 25480 observations are there
# in that 16k are from asia application
# out of 16K how many visa got certifird
# out of 16K how many visa got denied

# %%
c1=visa_df["continent"]=="Asia"
c2=visa_df["case_status"]=="Certified"
con=c1&c2
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N           2412.0       2002.0
# ...

# %%
c1=visa_df["continent"]=="Asia"
c2=visa_df["case_status"]=="Certified"
con=c1&c2
certified_count=len(visa_df[con])
print(f"there are {certified_count} got certified from asia.")
# Out:
# there are 11012 got certified from asia.

# %%
c1=visa_df["continent"]=="Asia"
c2=visa_df["case_status"]=="Certified"
c3=visa_df["case_status"]=="Denied"
cer_con=c1&c2
den_con=c1&c3
certified_count=len(visa_df[cer_con])
denied_count=len(visa_df[den_con])
print(f"there are {certified_count} got certified from asia.")
print(f"there are {denied_count} got denied from asia.")
# Out:
# there are 11012 got certified from asia.
# there are 5849 got denied from asia.

# %%
c1=visa_df["continent"]='Asia'
c1
# Out:
# 'Asia'

# %%
path=r"C:\Users\veeranna\DATA SCIENCE\Data_sets\Visadataset.xlsx"
visa_df=pd.read_excel(path)
unique_lable=visa_df["continent"].unique()
print(unique_lable)
l1,l2=[],[]
for i in unique_lable:
    c1=visa_df["continent"]==i
    c2=visa_df["case_status"]=="Certified"
    c3=visa_df["case_status"]=="Denied"
    cer_con=c1&c2
    den_con=c1&c3
    l1.append(len(visa_df[cer_con]))
    l2.append(len(visa_df[den_con]))
print(l1)
d1=pd.DataFrame(zip(unique_lable,l1,l2),columns=["continent","certified","Denied"])    
d1
# Out:
# ['Asia' 'Africa' 'North America' 'Europe' 'South America' 'Oceania']
# [11012, 397, 2037, 2957, 493, 122]
#        continent  certified  Denied
# 0           Asia      11012    5849
# 1         Africa        397     154
# 2  North America       2037    1255
# 3         Europe       2957     775
# 4  South America        493     359
# 5        Oceania        122      70

# %% [markdown]
# **set_index**

# %%
d1.set_index("continent")
# Out:
#                certified  Denied
# continent
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
# **pd.crosstab()**
# - will two arguments
# - index
# - column

# %%
col1=visa_df["continent"]
col2=visa_df["case_status"]
result1=pd.crosstab(col1,col2)
result1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
col1=[visa_df["continent"],
      visa_df["education_of_employee"]]
col2=visa_df["case_status"]
result2=pd.crosstab(col1,col2)
result2
# Out:
# case_status                          Certified  Denied
# continent     education_of_employee
# Africa        Bachelor's                    81      62
#               Doctorate                     43      11
#               High School                   23      43
#               Master's                     250      38
# Asia          Bachelor's                  4407    2761
#               Doctorate                    780     143
#               High School                  676    1614
#               Master's                    5149    1331
# Europe        Bachelor's                  1040     259
#               Doctorate                    788      58
#               High School                  162     328
#               Master's                     967     130
# North America Bachelor's                   641     584
#               Doctorate                    207      51
#               High School                  210     191
# ...

# %%
col1=[visa_df["continent"],
      visa_df["education_of_employee"]]
col2=visa_df["case_status"]
result3=pd.crosstab(col2,col1)
result3
# Out:
# continent                 Africa                                      Asia  \
# education_of_employee Bachelor's Doctorate High School Master's Bachelor's
# case_status
# Certified                     81        43          23      250       4407
# Denied                        62        11          43       38       2761
#
# continent                                                Europe            \
# education_of_employee Doctorate High School Master's Bachelor's Doctorate
# case_status
# Certified                   780         676     5149       1040       788
# Denied                      143        1614     1331        259        58
#
# continent              ... North America             Oceania            \
# education_of_employee  ...   High School Master's Bachelor's Doctorate
# case_status            ...
# Certified              ...           210      979         38        19
# Denied                 ...           191      429         28         3
#
# ...

# %%
result1.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
result2.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='continent,education_of_employee'>

# %%
result3.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='case_status'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\veeranna\DATA SCIENCE\Data_sets\Visadataset.xlsx"
visa_df=pd.read_excel(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N          14513.0       2007.0
# ...

# %% [markdown]
# **numarical vs numarical**

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
#(1,1)

# %% [markdown]
# **plt.scatter**

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[i for i in range(-4,5)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
#extract only numarical columns

# %%
num_cols=visa_df.select_dtypes(exclude='object')
num_cols.columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
col1=visa_df["no_of_employees"]
col2=visa_df["prevailing_wage"]
plt.scatter(col1,col2)
plt.show()  #no relation

# %%
**Pearson corretation coeffitiont**
- r varies from -1 to 1
- -1 to 0:negative relation
- 0 to 1:positive relation
- 0: no relation

# %%
- when you do this python will give the matrix

- in visa data 3 numarical columns are there

- python will give a matrix w.r.t 3 numerical columns

- the values in each field tells about the relation between the variables

# %%
visa_df.corr()  #sometimes works somes times wont
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
visa_df(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20732/3713471830.py in <module>
# ----> 1 visa_df(numeric_only=True)
#
# TypeError: 'DataFrame' object is not callable

# %%
#check the scatter plot between year of estab with prevailing wage
#we are seeing the relation is 0.01234

# %%
col1=visa_df["yr_of_estab"]
col2=visa_df["prevailing_wage"]
plt.scatter(col1,col2)
plt.show()

# %%
path=r"C:\Users\veeranna\DATA SCIENCE\Data_sets\winequality_red.xlsx"
wine=pd.read_excel(path)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#fixed acidity and citric acid :0.67 +ve

# %%
col1=wine["fixed acidity"]
col2=wine["citric acid"]
plt.scatter(col1,col2) #+ve

# %%
col2=wine["fixed acidity"]
col1=wine["citric acid"]
plt.scatter(col1,col2)

# %%
col1=wine["fixed acidity"]
col2=wine["pH"]
plt.scatter(col1,col2) #-ve

# %%
col2=wine["fixed acidity"]
col1=wine["pH"]
plt.scatter(col1,col2)

# %% [markdown]
# **heat map**

# %% [markdown]
# - heat is usefull to visualization of matrix
# - it is under seaborn packeg
# - heat map will varies the values and gives the color about the values

# %%
corr_visa=visa_df.corr()
corr_visa
#this is a matrix and we want to apply a heat map
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
sns.heatmap(corr_visa)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr_visa,annot=True)
# Out:
# <AxesSubplot:>

# %%
corr_wine=wine.corr()
corr_wine
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_wine,annot=True)
# Out:
# <AxesSubplot:>
